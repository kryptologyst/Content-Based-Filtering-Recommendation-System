# %% [markdown]
# # Content-Based Filtering Experimentation
#
# This notebook demonstrates the content-based filtering recommendation system with various experiments and visualizations.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd() / "src"))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from content_based_recommender import ContentBasedRecommender, create_sample_data
from data_utils import DataLoader, DataSplitter
from evaluation import ModelEvaluator, run_evaluation_experiment
from visualization import plot_metrics_comparison, plot_genre_distribution

# Set up plotting
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
